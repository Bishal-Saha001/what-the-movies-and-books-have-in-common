# %% [markdown]
# # Books preprocessing: initial findings
#
# In this section, we start to work with book datasets lookinf for initial findings! But first, we need to check the information there and apply some preprocessing and wrangling steps.

# %% [markdown]
# ## Importing Data

# %% [markdown]
# Importing relevant pachages:

# %%
from scipy import stats
import re
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Importing `book1.csv` and `book2.csv` from the `interim` folder:

# %%
df_book1 = pd.read_csv('../Data/interim/books/book1.csv', index_col=False)

# %%
df_book1.dropna(subset=['description'], inplace=True)

# %%
df_book2 = pd.read_csv('../Data/interim/books/book2.csv', index_col=False)

# %%
df_book2.dropna(subset=['description'], inplace=True)

# %%
df_book = pd.concat([df_book1, df_book2])

# %% [markdown]
# Inspecting the resultant dataFrame:

# %%
df_book.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 825175 entries, 1 to 499996
# Data columns (total 29 columns):
# asin                    141201 non-null object
# authors                 825175 non-null object
# average_rating          825175 non-null float64
# book_id                 825175 non-null int64
# country_code            825175 non-null object
# description             825175 non-null object
# edition_information     84392 non-null object
# format                  661449 non-null object
# image_url               825175 non-null object
# is_ebook                825175 non-null object
# isbn                    502210 non-null object
# isbn13                  583432 non-null object
# kindle_asin             361286 non-null object
# language_code           492893 non-null object
# link                    825175 non-null object
# num_pages               612922 non-null float64
# popular_shelves         825175 non-null object
# publication_day         529733 non-null float64
# ...

# %% [markdown]
# ## Data wrangling
#
# We note that some columns are not complete (`publiser`, `isbn`), but we focus just in relevant columns, as:
# - authors
# - average_rating
# - book_id
# - description
# - is_ebook
# - language_code
# - num_pages
# - publication_year
# - ratings_count
# - similar_books
# - title

# %%
df_book_ = df_book.copy()
df_book_ = df_book_.loc[:, ['authors', 'average_rating', 'book_id', 
                            'description', 'is_ebook', 'language_code',
                            'num_pages', 'publication_year', 'ratings_count',
                            'similar_books', 'title']]

# %% [markdown]
# Some questions that we must answer are, for instances:
#
# 1. Are we including dictionaries in this analysis? Number of pages of dictionaries are larger than common books.
# 2. Are data about publication year consistent and correct?
# 3. How many people evaluated the books on the ranking? A book with one evaluation can't be consider in the same category of books with hundred or thousand of evaluations.
# 4. Must be delete the books with incomplete data? Probably not, because using the language code as criteria we should delete almost 40% of books, but in opposite, we see that descriptions, titles and authors are complete.

# %% [markdown]
# ### I. Doesn’t  include dictionaries

# %%
dictionary = []
for title in df_book.title:
    if re.search(r'dictionary', str(title).lower()) is None:
        dictionary.append(0)
    else:
        dictionary.append(1)
        
df_book['is_dictionary'] = dictionary

# %%
df_book.groupby('is_dictionary').count()
# Out:
#                  asin  authors  average_rating  book_id  country_code  \
# is_dictionary
# 0              141187   824679          824679   824679        824679
# 1                  14      496             496      496           496
#
#                description  edition_information  format  image_url  is_ebook  \
# is_dictionary
# 0                   824679                84337  661011     824679    824679
# 1                      496                   55     438        496       496
#
#                 ...     publication_year  publisher  ratings_count  series  \
# is_dictionary   ...
# 0               ...               675273     653174         824679  824679
# 1               ...                  445        442            496     496
#
#                similar_books  text_reviews_count   title  \
# is_dictionary
# 0                     824679              824679  824678
# 1                        496                 496     496
#
# ...

# %% [markdown]
# There are almost 500 documents belongs to the category of Dictionary. We filter them using `is_dictionary`:

# %%
df_book_noDict = df_book[df_book['is_dictionary'] == 0]

# %% [markdown]
# ### II. Outliers in rating counts

# %% [markdown]
# If we are curious to work with the `average_rating` of books, we need to consider how many `rating_count` has every one and delete **outliers**. For instance, the `average_rating` of books with just one `rating_count` can't be compared with other with one hundred of counts. To deal with these differences, we calculate the **z score** of every rating count and filter books with z > 3 (standard threshold).

# %%
z = np.abs(stats.zscore(df_book_noDict.ratings_count))

# %%
df_book_noDict = df_book_noDict[(z < 3)]

# %% [markdown]
# ### III. Average Rating vs Absolute Ratings
#
# We add an absolute rating column that round ratings to get scores between 0 and 5:

# %%
df_book_noDict['abs_rating'] = round(df_book_noDict.average_rating)

# %% [markdown]
# ### IV. Outliers in number of pages

# %%
df_book_noDict.dropna(subset=['num_pages'], inplace=True)
#np.abs(stats.zscore(df_book_noDict.num_pages))

# %%
z_pages = np.abs(stats.zscore(df_book_noDict.num_pages))
df_book_noDict = df_book_noDict[(z_pages < 3)]

# %% [markdown]
# ### V. Publication year: sanity check
#
# Some books have more than one year in the `publicacion_year` column, because in some cases there is re-publication of the documents.

# %%
# a, b = df_book_noDict.publication_year[100].items()
# print(a[1],b[1])

# %%
df_book_noDict.dropna(subset=['publication_year'], inplace=True)
z_year = np.abs(stats.zscore(df_book_noDict.publication_year))
df_book_noDict_year = df_book_noDict[(z_year < 3)]

# %% [markdown]
# And in that case, we choose the first date defining a new `year` column on `df_book_noDict` dataFrame.

# %%
# year_unpack = []
# for year in df_book_noDict.publication_year:
#     if isinstance(year, float):
#         year_unpack.append(year)
#     else:
#         i, j = year
#         year_unpack.append(a)

# df_book_noDict['year'] = year_unpack

# %% [markdown]
# Then, we build a `df_book_noDict_year` that delete missing years.

# %%
#df_book_noDict_year = df_book_noDict.dropna(subset=['year'])

# %% [markdown]
# ### Average rating and number of pages
#
# The first inspection is about the average_rating and the number of pages, with additional information about the format of the books (e-book or not). Only books with rating non-null are considered and number of pages less than ten thousand.

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.set_style("white")
df_book_subset = df_book_noDict[(df_book_noDict.average_rating > 0) & \
                                (df_book_noDict.publication_year < 2020) & \
                                (df_book_noDict.publication_year > 1800)]
cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
ax = sns.scatterplot(x="publication_year", y="average_rating",
                     hue="is_ebook",
                     data=df_book_subset)
_ = sns.despine(offset=10, trim=True)

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.set_style("white")
df_book_subset = df_book_noDict[(df_book_noDict.average_rating > 0) & \
                                (df_book_noDict.publication_year < 2020) & \
                                (df_book_noDict.publication_year > 1800)]
cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
ax = sns.scatterplot(x="publication_year", y="num_pages",
                     hue="is_ebook",
                     data=df_book_subset)
_ = sns.despine(offset=10, trim=True)

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.set_style("white")
df_book_subset = df_book_noDict[(df_book_noDict.average_rating > 0) & \
                                (df_book_noDict.publication_year < 2020) & \
                                (df_book_noDict.publication_year > 1800)]
cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
ax = sns.scatterplot(x="num_pages", y="average_rating",
                     hue="is_ebook",
                     data=df_book_subset)
_ = sns.despine(offset=10, trim=True)

# %%
ax = sns.boxplot(x="abs_rating", y="num_pages", data=df_book_noDict)

# %% [markdown]
# Delete Nan and publication years before 1900 and after 2020:

# %%
df_book_noDict_year = df_book_noDict[(df_book_noDict.publication_year < 2020) & \
                                     (df_book_noDict.publication_year > 1900)]

# %%
_ = plt.hist(df_book_noDict_year.publication_year, bins=50)
plt.show()

# %%
df_book_1 = df_book_noDict_year[(df_book_noDict_year.num_pages < 10000) & (df_book_noDict_year.average_rating > 0)]
ax = sns.scatterplot(x="publication_year", y="average_rating",
                     hue="is_ebook",
                     data=df_book_1)

# %%
df_languages = df_book_noDict.groupby("language_code").count()
df_languages = df_languages[df_languages.asin > 100]

# %%
f, ax = plt.subplots(figsize=(6, 6))
_ = sns.set_style("white")
ax = sns.barplot(x=df_languages.index, y='asin', data=df_languages)
ax.set_yscale('log')
_ = plt.xlabel('Language', fontsize=10)
_ = plt.ylabel('Number of books', fontsize=10)
_ = plt.title('Common languages in books', fontsize=14)
_ = sns.despine(offset=10, trim=True)

# %%
l = []
for language in df_book_noDict['language_code']:
    if language in ['en-CA', 'en-GB', 'en-US', 'eng', 'en']:
        l.append('eng')
    else:
        l.append(language)

df_book_noDict['language'] = l      
df_languages = df_book_noDict.groupby("language").count()
df_languages = df_languages[df_languages.asin > 50]

# %%
f, ax = plt.subplots(figsize=(6, 6))
_ = sns.set_style("white")
ax = sns.barplot(x=df_languages.index, y='asin', data=df_languages, palette="deep")
ax.set_yscale('log')
_ = plt.xlabel('language', fontsize=10)
_ = plt.ylabel('number of books', fontsize=10)
_ = plt.title('Common languages in books', fontsize=14)
_ = sns.despine(offset=10, trim=True)

# %%
df_book_english = df_book_noDict_year[(df_book_noDict_year.language_code == 'eng') |
                                      (df_book_noDict_year.language_code == 'en-CA') |
                                      (df_book_noDict_year.language_code == 'en-GB') |
                                      (df_book_noDict_year.language_code == 'en-US') |
                                      (df_book_noDict_year.language_code == 'en')]

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.set_style("white")
df_book_2 = df_book_english[(df_book_english.num_pages < 10000) & (df_book_english.average_rating > 0)]
ax = sns.scatterplot(y="num_pages", x="average_rating",
                     hue="language_code",
                     data=df_book_2)
_ = plt.xlabel('number of pages', fontsize=8)
_ = plt.ylabel('average rating', fontsize=8)
_ = plt.title('Relation between rating and number of pages of English books', fontsize=12)
_ = sns.despine(offset=10, trim=True)

# %%
df_book_2['abs_rating'] = round(df_book_2.average_rating)
# Out:
# /Users/daniela/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_book_2.loc[df_book_2.average_rating == 1, 'category'] = 'Poor'
df_book_2.loc[df_book_2.average_rating == 2, 'category'] = 'Fair'
df_book_2.loc[df_book_2.average_rating == 3, 'category'] = 'Neutral'
df_book_2.loc[df_book_2.average_rating == 4, 'category'] = 'Good'
df_book_2.loc[df_book_2.average_rating == 5, 'category'] = 'Excellent'

f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.set_style("white")
ax = sns.scatterplot(x="publication_year", y="num_pages",
                     hue="category",
                     palette='Set2',
                     data=df_book_2)
_ = plt.xlabel('publication year')
_ = plt.ylabel('num pages')
_ = plt.title('Num pages of English books along time')
_ = sns.despine(offset=10, trim=True)

#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# Out:
# /Users/daniela/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/daniela/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df_book_popular_languages = df_book_noDict_year[(df_book_noDict_year.language_code == 'eng') |
                                      (df_book_noDict_year.language_code == 'en-CA') |
                                      (df_book_noDict_year.language_code == 'en-GB') |
                                      (df_book_noDict_year.language_code == 'en-US') |
                                      (df_book_noDict_year.language_code == 'en') |
                                      (df_book_noDict_year.language_code == 'fre') |
                                      (df_book_noDict_year.language_code == 'ge') |
                                      (df_book_noDict_year.language_code == 'spa') |
                                      (df_book_noDict_year.language_code == 'por') |
                                      (df_book_noDict_year.language_code == 'ita') |
                                      (df_book_noDict_year.language_code == 'ara')]

# %%
df_book_romance = df_book_noDict_year[
                                      (df_book_noDict_year.language_code == 'fre') |
                                      (df_book_noDict_year.language_code == 'spa') |
                                      (df_book_noDict_year.language_code == 'por') |
                                      (df_book_noDict_year.language_code == 'ita')]

# %%
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.set_style("white")
ax = sns.scatterplot(x="publication_year", y="average_rating",
                     hue="language_code",
                     palette='Set2',
                     data=df_book_romance)
_ = plt.xlabel('publication year')
_ = plt.ylabel('num pages')
_ = plt.title('Num pages of English books along time')
_ = sns.despine(offset=10, trim=True)

#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# ### Arabic books
#
# Arabic books are present from.....

# %%
df_book_arabe = df_book_noDict[(df_book_noDict.language_code == 'ara') & \
                               (df_book_noDict.publication_year < 2020) &\
                               (df_book_noDict.publication_year > 500)]

# %%
df_book_arabe.sort_values('publication_year')
# Out:
#               asin                                            authors  \
# 690            NaN            [{'author_id': '15417760', 'role': ''}]
# 329397         NaN             [{'author_id': '1270413', 'role': ''}]
# 114861         NaN             [{'author_id': '1270413', 'role': ''}]
# 157711         NaN        [{'author_id': '3052820', 'role': 'lkhTT'}]
# 257678         NaN  [{'author_id': '3293267', 'role': ''}, {'autho...
# 2602           NaN             [{'author_id': '1327003', 'role': ''}]
# 449510         NaN             [{'author_id': '3042252', 'role': ''}]
# 172362         NaN             [{'author_id': '3004513', 'role': ''}]
# 333675         NaN             [{'author_id': '3036541', 'role': ''}]
# 63452          NaN             [{'author_id': '3054851', 'role': ''}]
# 22184          NaN            [{'author_id': '13958792', 'role': ''}]
# 427208         NaN             [{'author_id': '3000730', 'role': ''}]
# ...

# %%
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.set_style("white")
ax = sns.scatterplot(x="publication_year", y="average_rating",
                     hue="language_code",
                     palette='Set2',
                     data=df_book_arabe)
_ = plt.xlabel('publication year')
_ = plt.ylabel('num pages')
_ = plt.title('Num pages of English books along time')
_ = sns.despine(offset=10, trim=True)

#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df_top1000 = df_book_noDict_year.sort_values(['publication_year', 'ratings_count', 'average_rating'], ascending=False).head(1000)

# %%
df_top1000.loc[:, ['title','publication_year', 'ratings_count', 'average_rating', 'language_code']]
# Out:
#                                                     title  publication_year  \
# 107252      Too Wicked To Kiss (Scoundrels & Secrets, #1)            2019.0
# 168179                                        Bảy năm sau            2019.0
# 132135  Roses and Thorns: The Reality of My Rock and R...            2019.0
# 353807                                  King Grisly-Beard            2019.0
# 416992  Jack West Jr and the Hero's Helmet (Jack West ...            2019.0
# 110110          All The Gods Below (The Arclight Saga #3)            2019.0
# 73074                                              كن أنت            2019.0
# 307256                  The Continent (The Continent, #1)            2018.0
# 276470                   Force of Nature (Aaron Falk, #2)            2018.0
# 455760                          War Storm (Red Queen, #4)            2018.0
# 115236                                     The Music Shop            2018.0
# ...

# %%
df_top1000_rating = df_book_noDict_year.sort_values(['ratings_count', 'average_rating', 'publication_year'], ascending=False).head(1000)

# %%
df_top1000_rating.loc[:, ['title','publication_year', 'ratings_count', 'average_rating', 'language_code']]
# Out:
#                                                     title  publication_year  \
# 207973                        King's Cage (Red Queen, #3)            2017.0
# 274254                                             Psycho            1999.0
# 176297                                        Montana Sky            2006.0
# 68426                                       Then Came You            2011.0
# 282348                                              Ariel            1999.0
# 80881                                    A Man Called Ove            2014.0
# 99104                                   A Town Like Alice            2000.0
# 452296  Packing for Mars: The Curious Science of Life ...            2010.0
# 424718              Takedown Twenty (Stephanie Plum, #20)            2013.0
# 70406                                The Story About Ping            2000.0
# 144054                               The Railway Children            2000.0
# ...

# %%
df_book_esential = df_book_.loc[:, ['book_id', 'title', 'description']]

# %% [markdown]
# # Books Review preprocessing

# %%
df_reviews = pd.read_csv('../Data/interim/books/books_reviews.csv', index_col=False)

# %%
df_reviews.head(2)
# Out:
#     book_id  has_spoiler  rating                         review_id  \
# 0  18245960         True       5  dfdbb7b0eb5a7e4c26d59a937e2e5feb
# 1     16981        False       3  a5d2c3628987712d0e05c4f90798eb67
#
#                                     review_sentences   timestamp  \
# 0  [[0, 'This is a special book.'], [0, 'It start...  2017-08-30
# 1  [[0, 'Recommended by Don Katz.'], [0, 'Avail f...  2017-03-22
#
#                             user_id
# 0  8842281e1d1347389f2ab93d60773d4d
# 1  8842281e1d1347389f2ab93d60773d4d

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1378033 entries, 0 to 1378032
# Data columns (total 7 columns):
# book_id             1378033 non-null int64
# has_spoiler         1378033 non-null bool
# rating              1378033 non-null int64
# review_id           1378033 non-null object
# review_sentences    1378033 non-null object
# timestamp           1378033 non-null object
# user_id             1378033 non-null object
# dtypes: bool(1), int64(2), object(4)
# memory usage: 64.4+ MB

# %%
df_books_reviews = df_reviews.merge(df_book_esential)

# %%
df_books_reviews.head(2)
# Out:
#    book_id  has_spoiler  rating                         review_id  \
# 0    16981        False       3  a5d2c3628987712d0e05c4f90798eb67
# 1    16981        False       4  706a8032efbde550167bf0d96c2ab501
#
#                                     review_sentences   timestamp  \
# 0  [[0, 'Recommended by Don Katz.'], [0, 'Avail f...  2017-03-22
# 1  [[0, 'This book was actually good, so long tho...  2015-02-25
#
#                             user_id          title  \
# 0  8842281e1d1347389f2ab93d60773d4d  Invisible Man
# 1  2159f55d397e8fbe68d5e03668e7d9d2  Invisible Man
#
#                                          description
# 0  First published in 1952 and immediately hailed...
# 1  First published in 1952 and immediately hailed...

# %% [markdown]
# #### NLP preprocessing

# %% [markdown]
# In this section we apply NLP pre-processing techniques such as subtraction of special characters, tokenization and lemmatization of the words. We define a pre-processing function as a pipeline of the methods mentioned and a sentiment_parameters_Pattern that calculate the polarity and subjectivity pattern of every review. In this case, we measure polarity using TextBlob and Afinn. Finally, we include the review normalized and the sentiment patterns using TextBlob and Afinn on the books_reviews dataFrame and save as csv file.

# %%
from nltk.stem import WordNetLemmatizer 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from textblob.sentiments import PatternAnalyzer
from textblob import TextBlob
import nltk

wpt = nltk.WordPunctTokenizer()
lemmatizer = WordNetLemmatizer() 

def pre_processing(text):
    text = re.sub(r'’',"'", text) # Rememeber that this step is to apply the stopword list that you used in the previous project.
    text = text.lower()
    # Filtering special characters
    text = re.sub(r'[^a-zA-Z\s]','', text)
    # Tokenization and filtering stop-words
    tokens = wpt.tokenize(text)
    # Lemmatization
    words_lem = [lemmatizer.lemmatize(word) for word in tokens]
    text_norm = ' '.join(words_lem)
    
    return text_norm

def sentiment_parameters_Pattern(sentence):
    blob = TextBlob(sentence, analyzer=PatternAnalyzer())
    return blob.sentiment.polarity, blob.sentiment.subjectivity

# %% [markdown]
# Normalizing `reviews_sentences`:

# %%
text_normalized = [pre_processing(text) for text in df_books_reviews['review_sentences']]

# %% [markdown]
# Saving the normalized reviews as a new column of `df_books_reviews`

# %%
df_books_reviews['text_normalized'] = text_normalized

# %% [markdown]
# Measure the polarity and subjectivity patterns of every review normalized:

# %%
sentiment_pattern = [sentiment_parameters_Pattern(text) for text in text_normalized]

# %% [markdown]
# Saving new columns with the patterns extracted in `df_books_reviews`:

# %%
polarity_textBlob = [sentiment_pattern[i][0] for i in range(len(sentiment_pattern))]
subjectivity_textBlob = [sentiment_pattern[j][1] for j in range(len(sentiment_pattern))]
df_books_reviews['polarity_textBlob'] = polarity_textBlob
df_books_reviews['subjectivity_textBlob'] = subjectivity_textBlob

# %% [markdown]
# Now, we'll use AFINN lexicon to measure the polarity of the sentences.

# %%
import sys
#!{sys.executable} -m pip install afinn
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/86/e5/ffbb7ee3cca21ac6d310ac01944fb163c20030b45bda25421d725d8a859a/afinn-0.1.tar.gz
# ...
#   Running setup.py bdist_wheel for afinn ... done
#   Stored in directory: /Users/daniela/Library/Caches/pip/wheels/b5/1c/de/428301f3333ca509dcf20ff358690eb23a1388fbcbbde008b2
# Successfully built afinn
# ...

# %%
from afinn import Afinn
af = Afinn()

# %% [markdown]
# We measure the polarity according AFINN lexicon and then, we classify the sentences in positive, negative or neutral, depending on the polarity score. Then, we include both as new columns of `df_books_reviews`.

# %%
sentiment_scores = [af.score(text) for text in text_normalized]

# %%
sentiment_category = ['positive' if score > 0 
                          else 'negative' if score < 0 
                              else 'neutral' 
                                  for score in sentiment_scores]

# %%
df_books_reviews['sentiment_scores'] = sentiment_scores
df_books_reviews['sentiment_category'] = sentiment_category

# %%
df_books_reviews.head()
# Out:
#    book_id  has_spoiler  rating                         review_id  \
# 0    16981        False       3  a5d2c3628987712d0e05c4f90798eb67
# 1    16981        False       4  706a8032efbde550167bf0d96c2ab501
# 2    16981        False       3  f72cb35f64a70beeda185dd744782b53
# 3    16981        False       5  479f6fb2c99aebcce518c9c1fe135d9d
# 4    16981        False       3  79e6d2ece4e328f79af96bb4ff58551e
#
#                                     review_sentences   timestamp  \
# 0  [[0, 'Recommended by Don Katz.'], [0, 'Avail f...  2017-03-22
# 1  [[0, 'This book was actually good, so long tho...  2015-02-25
# 2  [[0, 'Immensely complicated look at the many f...  2014-03-09
# 3  [[0, 'This is 16 cds, read by Joe Morton, and ...  2017-07-26
# 4  [[0, "It's been on my list for a while."], [0,...  2016-12-01
#
#                             user_id          title  \
# 0  8842281e1d1347389f2ab93d60773d4d  Invisible Man
# 1  2159f55d397e8fbe68d5e03668e7d9d2  Invisible Man
# ...

# %% [markdown]
# And we save the file in the `processed` folder

# %%
#df_books_reviews.to_csv('../Data/processed/sentiment_patterns_books_reviews.csv')

# %% [markdown]
# #### Inspecting the pattern results:

# %%
df_books_reviews.head(50)
# Out:
#     book_id  has_spoiler  rating                         review_id  \
# 0     16981        False       3  a5d2c3628987712d0e05c4f90798eb67
# 1     16981        False       4  706a8032efbde550167bf0d96c2ab501
# 2     16981        False       3  f72cb35f64a70beeda185dd744782b53
# 3     16981        False       5  479f6fb2c99aebcce518c9c1fe135d9d
# 4     16981        False       3  79e6d2ece4e328f79af96bb4ff58551e
# 5     16981        False       0  6265bb4bc8404d30022cc95c6169e707
# 6     16981        False       5  54704a83ba33e38f28e840908e3b64b2
# 7     16981        False       4  9180f27267dcefdba252ba69df8ee547
# 8     16981        False       5  5861049773365eaa6713a1973485fd9d
# 9     16981        False       4  e32b249d4e293a68dca01db5418d2c61
# 10    16981        False       3  b56c14c2297243fcfa4f03af9d55b4fc
# 11    16981        False       3  77cafc95a436e308d037e12dd03463c4
# 12    16981        False       5  da7611da021f21f919896a7f84642186
# ...

# %%
def normalizer(data):
    Min = np.nanmin(data)
    Max = np.nanmax(data)
    den = Max - Min 
    data_normalized = [(elem - Min)/den for elem in data]
    return data_normalized

afinn_polarity = normalizer(df_books_reviews['sentiment_scores'])
textblob_polarity = normalizer(df_books_reviews['polarity_textBlob'])

# %%
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.set_style("white")
ax = sns.scatterplot(x=afinn_polarity, y=textblob_polarity)
_ = plt.xlabel('AFINN polarity')
_ = plt.ylabel('TextBlob polarity')
_ = plt.title('Correlation between AFINN and TextBlob polarity patterns')
_ = sns.despine(offset=10, trim=True)

# %%
f, ax = plt.subplots(figsize=(5.5, 5.5))
_ = sns.set_style("white")
_ = sns.distplot(afinn_polarity, kde=False, norm_hist=True, label='AFINN')
_ = sns.distplot(textblob_polarity, kde=False, norm_hist=True, label='TextBlob')
_ = plt.xlabel('polarity')
_ = plt.ylabel('distribution')
_ = plt.title('Polarity distribution')
_ = sns.despine(offset=10, trim=True)
_ = plt.legend()

# %%
f, ax = plt.subplots(figsize=(6, 6))
_ = sns.set(style="whitegrid")
g = sns.stripplot(x="rating", y="sentiment_scores", hue='sentiment_category', data=df_books_reviews)
sns.despine(offset=10, trim=True)

# %%
textBlob_category = ['positive' if score > 0 
                          else 'negative' if score < 0 
                              else 'neutral' 
                                  for score in polarity_textBlob]

df_books_reviews['textBlob_category'] = textBlob_category

# %%
f, ax = plt.subplots(figsize=(6, 6))
_ = sns.set(style="whitegrid")
g = sns.stripplot(x="rating", y="polarity_textBlob", hue='textBlob_category', data=df_books_reviews)
sns.despine(offset=10, trim=True)

# %%
f, ax = plt.subplots(figsize=(15, 6))
_ = sns.set(style="whitegrid")
g = sns.boxplot(x="rating", y="subjectivity_textBlob", hue='sentiment_category', data=df_books_reviews)
sns.despine(offset=10, trim=True)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
import random

df_sample = df_books_reviews.sample(frac=0.01, random_state=42)

# %%
f, ax = plt.subplots(figsize=(18, 6.5))
sns.set_style("white")
ax = sns.swarmplot(x="rating", y="sentiment_scores",
                     palette='coolwarm',
                     data=df_sample)
_ = plt.xlabel('rating')
_ = plt.ylabel('Sentiment polarity score AFINN')
_ = plt.title('Polarity pattern AFINN along to the book rating scores')
_ = sns.despine(offset=10, trim=True)

# %%
f, ax = plt.subplots(figsize=(18, 6.5))
sns.set_style("white")
ax = sns.swarmplot(x="rating", y="polarity_textBlob",
                     palette='coolwarm',
                     data=df_sample)
_ = plt.xlabel('rating')
_ = plt.ylabel('Sentiment polarity score TextBlob')
_ = plt.title('Polarity pattern TextBlob along to the book rating scores')
_ = sns.despine(offset=10, trim=True)
